# %%
import requests

# %% [markdown]
# ## Step 1: Get Hospitalization Data
# We will retrieve the data from [this file](https://data.cdc.gov/Public-Health-Surveillance/Weekly-United-States-Hospitalization-Metrics-by-Ju/aemt-mg7g/about_data) on data.cdc.gov. This dataset represents weekly respiratory virus-related hospitalization data and metrics aggregated to national and state/territory levels.

# %%
hospitalizations_url = (
    "https://data.cdc.gov/resource/aemt-mg7g.json?jurisdiction=NC"
)
hosp_file = requests.get(hospitalizations_url)
hosp_file = hosp_file.json()
print(hosp_file)
hosp_data = []
last_number = 0
for row in hosp_file:
    admissions = int(row.get("total_admissions_all_covid_confirmed"))
    new_row = {
        "week_end_date": row.get("week_end_date"),
        "hospitalizations": last_number + admissions,
    }
    last_number += admissions
    hosp_data.append(new_row)
print(hosp_data)
# Out:
# [{'week_end_date': '2020-08-08T00:00:00.000', 'jurisdiction': 'NC', 'weekly_actual_days_reporting_any_data': '716', 'weekly_percent_days_reporting_any_data': '0.9384', 'num_hospitals_previous_day_admission_adult_covid_confirmed': '104', 'num_hospitals_previous_day_admission_pediatric_covid_confirmed': '81', 'num_hospitals_previous_day_admission_influenza_confirmed': '0', 'num_hospitals_total_patients_hospitalized_confirmed_influenza': '0', 'num_hospitals_icu_patients_confirmed_influenza': '0', 'num_hospitals_inpatient_beds': '105', 'num_hospitals_total_icu_beds': '105', 'num_hospitals_inpatient_beds_used': '105', 'num_hospitals_icu_beds_used': '104', 'num_hospitals_percent_inpatient_beds_occupied': '105', 'num_hospitals_percent_staff_icu_beds_occupied': '104', 'num_hospitals_percent_inpatient_beds_covid': '104', 'num_hospitals_percent_inpatient_beds_influenza': '0', 'num_hospitals_percent_staff_icu_beds_covid': '104', 'num_hospitals_percent_icu_beds_influenza': '0', 'num_hospitals_admissions_all_covid_confirmed': '104', 'num_hospitals_total_patients_hospitalized_covid_confirmed': '105', 'num_hospitals_staff_icu_patients_covid_confirmed': '105', 'avg_admissions_adult_covid_confirmed': '120.71', 'total_admissions_adult_covid_confirmed': '845', 'avg_admissions_pediatric_covid_confirmed': '1.0', 'total_admissions_pediatric_covid_confirmed': '7', 'avg_admissions_all_covid_confirmed': '121.71', 'total_admissions_all_covid_confirmed': '852', 'avg_total_patients_hospitalized_covid_confirmed': '853.71', 'avg_staff_icu_patients_covid_confirmed': '343.0', 'avg_inpatient_beds': '19673.14', 'avg_total_icu_beds': '2476.71', 'avg_inpatient_beds_used': '15953.14', 'avg_icu_beds_used': '1815.86', 'avg_percent_inpatient_beds_occupied': '0.8109', 'avg_percent_staff_icu_beds_occupied': '0.7342', 'avg_percent_inpatient_beds_covid': '0.0434', 'avg_percent_staff_icu_beds_covid': '0.1387', 'percent_adult_covid_admissions': '0.9918', 'percent_pediatric_covid_admissions': '0.0082', 'percent_hospitals_previous_day_admission_adult_covid_confirmed': '0.9369', 'percent_hospitals_previous_day_admission_pediatric_covid_confirmed': '0.7297', 'percent_hospitals_previous_day_admission_influenza_confirmed': '0.0', 'percent_hospitals_total_patients_hospitalized_confirmed_influenza': '0.0', 'percent_hospitals_icu_patients_confirmed_influenza': '0.0', 'percent_hospitals_inpatient_beds': '0.9459', 'percent_hospitals_total_icu_beds': '0.9459', 'percent_hospitals_inpatient_beds_used': '0.9459', 'percent_hospitals_icu_beds_used': '0.9369', 'percent_hospitals_percent_inpatient_beds_occupied': '0.9459', 'percent_hospitals_percent_staff_icu_beds_occupied': '0.9369', 'percent_hospitals_percent_inpatient_beds_covid': '0.9369', 'percent_hospitals_percent_inpatient_beds_influenza': '0.0', 'percent_hospitals_percent_staff_icu_beds_covid': '0.9369', 'percent_hospitals_percent_icu_beds_influenza': '0.0', 'percent_hospitals_admissions_all_covid_confirmed': '0.9369', 'percent_hospitals_total_patients_hospitalized_covid_confirmed': '0.9459', 'percent_hospitals_staff_icu_patients_covid_confirmed': '0.9459'}, {'week_end_date': '2020-08-15T00:00:00.000', 'jurisdiction': 'NC', 'weekly_actual_days_reporting_any_data': '685', 'weekly_percent_days_reporting_any_data': '0.8978', 'num_hospitals_previous_day_admission_adult_covid_confirmed': '108', 'num_hospitals_previous_day_admission_pediatric_covid_confirmed': '103', 'num_hospitals_previous_day_admission_influenza_confirmed': '0', 'num_hospitals_total_patients_hospitalized_confirmed_influenza': '0', 'num_hospitals_icu_patients_confirmed_influenza': '0', 'num_hospitals_inpatient_beds': '107', 'num_hospitals_total_icu_beds': '107', 'num_hospitals_inpatient_beds_used': '107', 'num_hospitals_icu_beds_used': '105', 'num_hospitals_percent_inpatient_beds_occupied': '107', 'num_hospitals_percent_staff_icu_beds_occupied': '105', 'num_hospitals_percent_inpatient_beds_covid': '106', 'num_hospitals_percent_inpatient_beds_influenza': '0', 'num_hospita ...
# [{'week_end_date': '2020-08-08T00:00:00.000', 'hospitalizations': 852}, {'week_end_date': '2020-08-15T00:00:00.000', 'hospitalizations': 1412}, {'week_end_date': '2020-08-22T00:00:00.000', 'hospitalizations': 2146}, {'week_end_date': '2020-08-29T00:00:00.000', 'hospitalizations': 3704}, {'week_end_date': '2020-09-05T00:00:00.000', 'hospitalizations': 5105}, {'week_end_date': '2020-09-12T00:00:00.000', 'hospitalizations': 5766}, {'week_end_date': '2020-09-19T00:00:00.000', 'hospitalizations': 6420}, {'week_end_date': '2020-09-26T00:00:00.000', 'hospitalizations': 7093}, {'week_end_date': '2020-10-03T00:00:00.000', 'hospitalizations': 7765}, {'week_end_date': '2020-10-10T00:00:00.000', 'hospitalizations': 8730}, {'week_end_date': '2020-10-17T00:00:00.000', 'hospitalizations': 9741}, {'week_end_date': '2020-10-24T00:00:00.000', 'hospitalizations': 10753}, {'week_end_date': '2020-10-31T00:00:00.000', 'hospitalizations': 11749}, {'week_end_date': '2020-11-07T00:00:00.000', 'hospitalizations': 12840}, {'week_end_date': '2020-11-14T00:00:00.000', 'hospitalizations': 14052}, {'week_end_date': '2020-11-21T00:00:00.000', 'hospitalizations': 15489}, {'week_end_date': '2020-11-28T00:00:00.000', 'hospitalizations': 17026}, {'week_end_date': '2020-12-05T00:00:00.000', 'hospitalizations': 18900}, {'week_end_date': '2020-12-12T00:00:00.000', 'hospitalizations': 21038}, {'week_end_date': '2020-12-19T00:00:00.000', 'hospitalizations': 23316}, {'week_end_date': '2020-12-26T00:00:00.000', 'hospitalizations': 25855}, {'week_end_date': '2021-01-02T00:00:00.000', 'hospitalizations': 28571}, {'week_end_date': '2021-01-09T00:00:00.000', 'hospitalizations': 31713}, {'week_end_date': '2021-01-16T00:00:00.000', 'hospitalizations': 34791}, {'week_end_date': '2021-01-23T00:00:00.000', 'hospitalizations': 37342}, {'week_end_date': '2021-01-30T00:00:00.000', 'hospitalizations': 39662}, {'week_end_date': '2021-02-06T00:00:00.000', 'hospitalizations': 41536}, {'week_end_date': '2021-02-13T00:00:00.000', 'hospitalizations': 43040}, {'week_end_date': '2021-02-20T00:00:00.000', 'hospitalizations': 44279}, {'week_end_date': '2021-02-27T00:00:00.000', 'hospitalizations': 45244}, {'week_end_date': '2021-03-06T00:00:00.000', 'hospitalizations': 46073}, {'week_end_date': '2021-03-13T00:00:00.000', 'hospitalizations': 46861}, {'week_end_date': '2021-03-20T00:00:00.000', 'hospitalizations': 47610}, {'week_end_date': '2021-03-27T00:00:00.000', 'hospitalizations': 48287}, {'week_end_date': '2021-04-03T00:00:00.000', 'hospitalizations': 49044}, {'week_end_date': '2021-04-10T00:00:00.000', 'hospitalizations': 49809}, {'week_end_date': '2021-04-17T00:00:00.000', 'hospitalizations': 50707}, {'week_end_date': '2021-04-24T00:00:00.000', 'hospitalizations': 51640}, {'week_end_date': '2021-05-01T00:00:00.000', 'hospitalizations': 52512}, {'week_end_date': '2021-05-08T00:00:00.000', 'hospitalizations': 53271}, {'week_end_date': '2021-05-15T00:00:00.000', 'hospitalizations': 53980}, {'week_end_date': '2021-05-22T00:00:00.000', 'hospitalizations': 54569}, {'week_end_date': '2021-05-29T00:00:00.000', 'hospitalizations': 55092}, {'week_end_date': '2021-06-05T00:00:00.000', 'hospitalizations': 55549}, {'week_end_date': '2021-06-12T00:00:00.000', 'hospitalizations': 55930}, {'week_end_date': '2021-06-19T00:00:00.000', 'hospitalizations': 56286}, {'week_end_date': '2021-06-26T00:00:00.000', 'hospitalizations': 56588}, {'week_end_date': '2021-07-03T00:00:00.000', 'hospitalizations': 56920}, {'week_end_date': '2021-07-10T00:00:00.000', 'hospitalizations': 57246}, {'week_end_date': '2021-07-17T00:00:00.000', 'hospitalizations': 57714}, {'week_end_date': '2021-07-24T00:00:00.000', 'hospitalizations': 58449}, {'week_end_date': '2021-07-31T00:00:00.000', 'hospitalizations': 59486}, {'week_end_date': '2021-08-07T00:00:00.000', 'hospitalizations': 60930}, {'week_end_date': '2021-08-14T00:00:00.000', 'hospitalizations': 62975}, {'week_end_date': '2021-08-21T00:00:00.000', 'hospitalizations': 6535 ...

# %% [markdown]
# ## Step 2: Get Vaccination Uptake Data
# Next we will get the vaccination update data from [this file](https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc/about_data) on data.cdc.gov. This dataset contains overall US COVID-19 Vaccine deliveries and administration data at national and jurisdiction level.

# %%
vaccinations_url = "https://data.cdc.gov/resource/unsk-b7fc.json?location=NC"
vacc_file = requests.get(vaccinations_url)
vacc_file = vacc_file.json()
vacc_data = []
for row in vacc_file:
    new_row = {"date": row.get("date"), "vaccinations": row.get("administered")}
    vacc_data.append(new_row)

# %%
print(vacc_data[0])
print(hosp_data[0])
# Out:
# {'date': '2023-05-10T00:00:00.000', 'vaccinations': '19434544'}
# {'week_end_date': '2020-08-08T00:00:00.000', 'hospitalizations': 852}

# %% [markdown]
# ## Step 3: Harmonize
# The data is not at the same time resolution, and one is cumulative and the other is raw counts. We can harmonize this data by defaulting to the one week timepoint.

# %%
harmonized = []
for row in hosp_data:

    def match_dates(x):
        return x.get("date") == row.get("week_end_date")

    matching_vacc_rows = list(filter(match_dates, vacc_data))

    if len(matching_vacc_rows):
        row["vaccinations"] = matching_vacc_rows[0].get("vaccinations")
        harmonized.append(row)
print(harmonized)
# Out:
# [{'week_end_date': '2020-12-19T00:00:00.000', 'hospitalizations': 23316, 'vaccinations': '8784'}, {'week_end_date': '2020-12-26T00:00:00.000', 'hospitalizations': 25855, 'vaccinations': '50570'}, {'week_end_date': '2021-01-02T00:00:00.000', 'hospitalizations': 28571, 'vaccinations': '102399'}, {'week_end_date': '2021-01-09T00:00:00.000', 'hospitalizations': 31713, 'vaccinations': '194478'}, {'week_end_date': '2021-01-16T00:00:00.000', 'hospitalizations': 34791, 'vaccinations': '374216'}, {'week_end_date': '2021-01-23T00:00:00.000', 'hospitalizations': 37342, 'vaccinations': '577007'}, {'week_end_date': '2021-01-30T00:00:00.000', 'hospitalizations': 39662, 'vaccinations': '898736'}, {'week_end_date': '2021-02-06T00:00:00.000', 'hospitalizations': 41536, 'vaccinations': '1171240'}, {'week_end_date': '2021-02-13T00:00:00.000', 'hospitalizations': 43040, 'vaccinations': '1523425'}, {'week_end_date': '2021-02-20T00:00:00.000', 'hospitalizations': 44279, 'vaccinations': '2008811'}, {'week_end_date': '2021-02-27T00:00:00.000', 'hospitalizations': 45244, 'vaccinations': '2366027'}, {'week_end_date': '2021-03-06T00:00:00.000', 'hospitalizations': 46073, 'vaccinations': '2760801'}, {'week_end_date': '2021-03-13T00:00:00.000', 'hospitalizations': 46861, 'vaccinations': '3391675'}, {'week_end_date': '2021-03-20T00:00:00.000', 'hospitalizations': 47610, 'vaccinations': '3903284'}, {'week_end_date': '2021-03-27T00:00:00.000', 'hospitalizations': 48287, 'vaccinations': '4456503'}, {'week_end_date': '2021-04-03T00:00:00.000', 'hospitalizations': 49044, 'vaccinations': '5008165'}, {'week_end_date': '2021-04-10T00:00:00.000', 'hospitalizations': 49809, 'vaccinations': '5527176'}, {'week_end_date': '2021-04-17T00:00:00.000', 'hospitalizations': 50707, 'vaccinations': '6148077'}, {'week_end_date': '2021-04-24T00:00:00.000', 'hospitalizations': 51640, 'vaccinations': '6650611'}, {'week_end_date': '2021-05-01T00:00:00.000', 'hospitalizations': 52512, 'vaccinations': '7078485'}, {'week_end_date': '2021-05-08T00:00:00.000', 'hospitalizations': 53271, 'vaccinations': '7435976'}, {'week_end_date': '2021-05-15T00:00:00.000', 'hospitalizations': 53980, 'vaccinations': '7692414'}, {'week_end_date': '2021-05-22T00:00:00.000', 'hospitalizations': 54569, 'vaccinations': '7937262'}, {'week_end_date': '2021-05-29T00:00:00.000', 'hospitalizations': 55092, 'vaccinations': '8121565'}, {'week_end_date': '2021-06-05T00:00:00.000', 'hospitalizations': 55549, 'vaccinations': '8228394'}, {'week_end_date': '2021-06-12T00:00:00.000', 'hospitalizations': 55930, 'vaccinations': '8357198'}, {'week_end_date': '2021-06-19T00:00:00.000', 'hospitalizations': 56286, 'vaccinations': '8501475'}, {'week_end_date': '2021-06-26T00:00:00.000', 'hospitalizations': 56588, 'vaccinations': '8597378'}, {'week_end_date': '2021-07-03T00:00:00.000', 'hospitalizations': 56920, 'vaccinations': '9321705'}, {'week_end_date': '2021-07-10T00:00:00.000', 'hospitalizations': 57246, 'vaccinations': '9408302'}, {'week_end_date': '2021-07-17T00:00:00.000', 'hospitalizations': 57714, 'vaccinations': '9500467'}, {'week_end_date': '2021-07-24T00:00:00.000', 'hospitalizations': 58449, 'vaccinations': '9597439'}, {'week_end_date': '2021-07-31T00:00:00.000', 'hospitalizations': 59486, 'vaccinations': '9722902'}, {'week_end_date': '2021-08-07T00:00:00.000', 'hospitalizations': 60930, 'vaccinations': '9866778'}, {'week_end_date': '2021-08-14T00:00:00.000', 'hospitalizations': 62975, 'vaccinations': '10015155'}, {'week_end_date': '2021-08-21T00:00:00.000', 'hospitalizations': 65357, 'vaccinations': '10182160'}, {'week_end_date': '2021-08-28T00:00:00.000', 'hospitalizations': 67936, 'vaccinations': '10391734'}, {'week_end_date': '2021-09-04T00:00:00.000', 'hospitalizations': 70582, 'vaccinations': '10611359'}, {'week_end_date': '2021-09-11T00:00:00.000', 'hospitalizations': 73103, 'vaccinations': '10801848'}, {'week_end_date': '2021-09-18T00:00:00.000', 'hospitalizations': 75485, 'vaccinations': '10981479'}, {'w ...

# %%
import pandas as pd
as_df = pd.DataFrame(harmonized)
print(as_df)
# Out:
#               week_end_date  hospitalizations vaccinations
# 0   2020-12-19T00:00:00.000             23316         8784
# 1   2020-12-26T00:00:00.000             25855        50570
# 2   2021-01-02T00:00:00.000             28571       102399
# 3   2021-01-09T00:00:00.000             31713       194478
# 4   2021-01-16T00:00:00.000             34791       374216
# ..                      ...               ...          ...
# 73  2022-05-14T00:00:00.000            122811     16863803
# 74  2022-05-21T00:00:00.000            123401     16933953
# 75  2022-05-28T00:00:00.000            124086     17015647
# 76  2022-06-04T00:00:00.000            124886     17078454
# 77  2022-06-11T00:00:00.000            125652     17143393
#
# [78 rows x 3 columns]

# %% [markdown]
# ## Step 4: Visualize
# Here we use matplotlib to visualize outputs and check coherence.

# %%
import matplotlib.pyplot as plt

dates = [w.get("week_end_date") for w in harmonized]
covid = [int(w.get("hospitalizations")) for w in harmonized]
vaccines = [int(w.get("vaccinations")) for w in harmonized]
fig, axs = plt.subplots(4, 1, layout="constrained")
axs[0].plot(dates, covid)
axs[0].tick_params(axis="x", labelrotation=45)
axs[0].set_xlabel("Date")
axs[0].set_ylabel("COVID Hospitalizations")
axs[0].grid(True)

axs[1].plot(dates, vaccines)
axs[1].set_xlabel("Date")
axs[1].tick_params(axis="x", labelrotation=45)
axs[1].set_ylabel("Vaccines Administered")
axs[1].grid(True)

axs[2].cohere(covid, vaccines, NFFT=16)
axs[2].set_ylabel("Coherence")
axs[2].tick_params(axis="x", labelrotation=45)

axs[3].csd(covid, vaccines)
axs[3].set_ylabel("CSD")
axs[3].tick_params(axis="x", labelrotation=45)

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /Users/aipuameh/CHIP690/lecture_20/.venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or Axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)
